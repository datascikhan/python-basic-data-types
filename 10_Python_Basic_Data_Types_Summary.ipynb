# %% [markdown]
# ## **9️⃣ Summary Table**

# %% [markdown]
# | Data Type | Mutable | Ordered | Allows Duplicates | Example |
# | --------- | ------- | ------- | ----------------- | ------- |
# | int       | No      | Yes     | Yes               | 10      |
# | float     | No      | Yes     | Yes               | 3.14    |
# | complex   | No      | Yes     | Yes               | 2+3j    |
# | str       | No      | Yes     | Yes               | "Alice" |
# | list      | Yes     | Yes     | Yes               | [1,2,3] |
# | tuple     | No      | Yes     | Yes               | (1,2,3) |
# | set       | Yes     | No      | No                | {1,2,3} |
# | dict      | Yes     | No      | Keys unique       | {"a":1} |
# | bool      | No      | N/A     | N/A               | True    |
